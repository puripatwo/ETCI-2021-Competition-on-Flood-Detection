# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Dec 10 10:20:10 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   33C    P0             53W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
# !git clone https://github.com/puripatwo/ETCI-2021-Competition-on-Flood-Detection.git
# Out:
# Cloning into 'ETCI-2021-Competition-on-Flood-Detection'...
# remote: Enumerating objects: 247, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 247 (delta 46), reused 48 (delta 24), pack-reused 165 (from 1)
# Receiving objects: 100% (247/247), 4.81 MiB | 20.43 MiB/s, done.
# Resolving deltas: 100% (131/131), done.

# %%
# !pip install -r ETCI-2021-Competition-on-Flood-Detection/requirements.txt
# !pip install git+https://github.com/qubvel/segmentation_models.pytorch
# !pip install git+https://github.com/lucasb-eyer/pydensecrf.git
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.0 MB/s eta 0:00:00
# WARNING: Ignoring version 22.4 of catalyst since it has invalid metadata:
# Requested catalyst from https://files.pythonhosted.org/packages/05/09/36a4acd1c3112f2e2da74f4340778100a205ecb59166be00dc6287f3364f/catalyst-22.4-py2.py3-none-any.whl (from -r ETCI-2021-Competition-on-Flood-Detection/requirements.txt (line 2)) has invalid metadata: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     scikit-image (<0.19.0>=0.16.1) ; extra == 'all'
#                  ~~~~~~~~^
# Please use pip<24.1 if you need to use this version.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 5.9 MB/s eta 0:00:00
# WARNING: Ignoring version 22.2.1 of catalyst since it has invalid metadata:
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/Colab Notebooks/final-UNOSAT-Dataset.zip" -d "/content/ETCI-2021-Competition-on-Flood-Detection/"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/ETCI-2021-Competition-on-Flood-Detection/final-ETCI-2021-Flood-Detection/data/test_internal/florence_20180709t231346/tiles/vv/florence_20180709t231346_x-7_y-1_vv.png
#   inflating: /content/ETCI-2021-Competition-on-Flood-Detection/final-ETCI-2021-Flood-Detection/data/test_internal/florence_20180709t231346/tiles/vv/florence_20180709t231346_x-10_y-29_vv.png
#   inflating: /content/ETCI-2021-Competition-on-Flood-Detection/final-ETCI-2021-Flood-Detection/data/test_internal/florence_20180709t231346/tiles/vv/florence_20180709t231346_x-12_y-22_vv.png
#   inflating: /content/ETCI-2021-Competition-on-Flood-Detection/final-ETCI-2021-Flood-Detection/data/test_internal/florence_20180709t231346/tiles/vv/florence_20180709t231346_x-22_y-13_vv.png
# ...

# %%
# %cd ETCI-2021-Competition-on-Flood-Detection
# Out:
# /content/ETCI-2021-Competition-on-Flood-Detection

# %%
# !python src/train.py --model_class='unet' --epochs=15 --round=0 --eval --backbone="mobilenet_v2"
# Out:
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# Created final-ETCI-2021-Flood-Detection/data/train dataframe with 27201 entries.
#                                        vv_image_path  ...    region
# 0  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 1  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 2  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 3  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 4  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
#
# [5 rows x 5 columns]
# Created final-ETCI-2021-Flood-Detection/data/test dataframe with 6204 entries.
#                                        vv_image_path  ...      region
# 0  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# 1  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# 2  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# ...

# %%
# !python src/train.py --model_class='unetplusplus' --epochs=15 --round=0 --eval --backbone="mobilenet_v2"
# Out:
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# Created final-ETCI-2021-Flood-Detection/data/train dataframe with 27201 entries.
#                                        vv_image_path  ...    region
# 0  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 1  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 2  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 3  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 4  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
#
# [5 rows x 5 columns]
# Created final-ETCI-2021-Flood-Detection/data/test dataframe with 6204 entries.
#                                        vv_image_path  ...      region
# 0  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# 1  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# 2  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# ...

# %%
# !python src/generate_pseudo.py \
  --model-defs="unet,unetplusplus" \
  --model-paths="src/model/round_0/unet_mobilenet_v2/saved_weights.pth,src/model/round_0/unetplusplus_mobilenet_v2/saved_weights.pth" \
  --backbone="mobilenet_v2"
# Out:
# Number of test temporal-regions: 10
# Created final-ETCI-2021-Flood-Detection/data/test_internal dataframe with 10400 entries.
#                                        vv_image_path  ...    region
# 0  final-ETCI-2021-Flood-Detection/data/test_inte...  ...  florence
# 1  final-ETCI-2021-Flood-Detection/data/test_inte...  ...  florence
# 2  final-ETCI-2021-Flood-Detection/data/test_inte...  ...  florence
# 3  final-ETCI-2021-Flood-Detection/data/test_inte...  ...  florence
# 4  final-ETCI-2021-Flood-Detection/data/test_inte...  ...  florence
#
# [5 rows x 5 columns]
# Generating pseudo-labels:   0% 0/109 [00:00<?, ?it/s][ WARN:0@11.033] global loadsave.cpp:1063 imwrite_ Unsupported depth image for selected encoder is fallbacked to CV_8U.
# Generating pseudo-labels: 100% 109/109 [03:52<00:00,  2.14s/it]
# Generated pseudo-labels for 10249 images.

# %%
# !python src/train_pseudo_label.py \
  --epochs=20 \
  --pretrained-path="src/model/round_0/unet_mobilenet_v2/saved_weights.pth" \
  --round=1 \
  --eval \
  --backbone="mobilenet_v2"
# Out:
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# Created final-ETCI-2021-Flood-Detection/data/train dataframe with 27201 entries.
#                                        vv_image_path  ...    region
# 0  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 1  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 2  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 3  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 4  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
#
# [5 rows x 5 columns]
# Created final-ETCI-2021-Flood-Detection/data/test dataframe with 6204 entries.
#                                        vv_image_path  ...      region
# 0  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# 1  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# 2  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# ...

# %%
# !python src/train.py --model_class='unet' --epochs=15 --round=1 --eval --backbone="mobilenet_v2"
# Out:
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# Created final-ETCI-2021-Flood-Detection/data/train dataframe with 27201 entries.
#                                        vv_image_path  ...    region
# 0  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 1  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 2  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 3  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 4  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
#
# [5 rows x 5 columns]
# Created final-ETCI-2021-Flood-Detection/data/test dataframe with 6204 entries.
#                                        vv_image_path  ...      region
# 0  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# 1  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# 2  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# ...

# %%
# !python src/train.py --model_class='unetplusplus' --epochs=15 --round=1 --eval --backbone="mobilenet_v2"
# Out:
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# Created final-ETCI-2021-Flood-Detection/data/train dataframe with 27201 entries.
#                                        vv_image_path  ...    region
# 0  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 1  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 2  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 3  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 4  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
#
# [5 rows x 5 columns]
# Created final-ETCI-2021-Flood-Detection/data/test dataframe with 6204 entries.
#                                        vv_image_path  ...      region
# 0  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# 1  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# 2  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# ...

# %%
# !python src/generate_pseudo.py \
  --model-defs="unet,unetplusplus,unet" \
  --model-paths="src/model/round_1/unet_mobilenet_v2/saved_weights.pth,src/model/round_1/unetplusplus_mobilenet_v2/saved_weights.pth,src/model/round_1/finetuned_unet_mobilenet_v2/saved_weights.pth" \
  --backbone="mobilenet_v2"
# Out:
# Number of test temporal-regions: 10
# Created final-ETCI-2021-Flood-Detection/data/test_internal dataframe with 10400 entries.
#                                        vv_image_path  ...    region
# 0  final-ETCI-2021-Flood-Detection/data/test_inte...  ...  florence
# 1  final-ETCI-2021-Flood-Detection/data/test_inte...  ...  florence
# 2  final-ETCI-2021-Flood-Detection/data/test_inte...  ...  florence
# 3  final-ETCI-2021-Flood-Detection/data/test_inte...  ...  florence
# 4  final-ETCI-2021-Flood-Detection/data/test_inte...  ...  florence
#
# [5 rows x 5 columns]
# Generating pseudo-labels:   0% 0/109 [00:00<?, ?it/s][ WARN:0@11.607] global loadsave.cpp:1063 imwrite_ Unsupported depth image for selected encoder is fallbacked to CV_8U.
# Generating pseudo-labels: 100% 109/109 [04:36<00:00,  2.53s/it]
# Generated pseudo-labels for 10398 images.

# %%
# !python src/train_pseudo_label.py \
  --epochs=20 \
  --pretrained-path="src/model/round_1/finetuned_unet_mobilenet_v2/saved_weights.pth" \
  --round=2 \
  --eval \
  --backbone="mobilenet_v2"
# Out:
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# Created final-ETCI-2021-Flood-Detection/data/train dataframe with 27201 entries.
#                                        vv_image_path  ...    region
# 0  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 1  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 2  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 3  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 4  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
#
# [5 rows x 5 columns]
# Created final-ETCI-2021-Flood-Detection/data/test dataframe with 6204 entries.
#                                        vv_image_path  ...      region
# 0  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# 1  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# 2  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# ...

# %%
# !python src/train.py --model_class='unet' --epochs=15 --round=2 --eval --backbone="mobilenet_v2"
# Out:
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# Created final-ETCI-2021-Flood-Detection/data/train dataframe with 27201 entries.
#                                        vv_image_path  ...    region
# 0  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 1  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 2  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 3  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 4  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
#
# [5 rows x 5 columns]
# Created final-ETCI-2021-Flood-Detection/data/test dataframe with 6204 entries.
#                                        vv_image_path  ...      region
# 0  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# 1  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# 2  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# ...

# %%
# !python src/train.py --model_class='unetplusplus' --epochs=15 --round=2 --eval --backbone="mobilenet_v2"
# Out:
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# Created final-ETCI-2021-Flood-Detection/data/train dataframe with 27201 entries.
#                                        vv_image_path  ...    region
# 0  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 1  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 2  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 3  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
# 4  final-ETCI-2021-Flood-Detection/data/train/neb...  ...  nebraska
#
# [5 rows x 5 columns]
# Created final-ETCI-2021-Flood-Detection/data/test dataframe with 6204 entries.
#                                        vv_image_path  ...      region
# 0  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# 1  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# 2  final-ETCI-2021-Flood-Detection/data/test/bang...  ...  bangladesh
# ...

# %%
# !python src/ensemble_inference.py \
  --model-defs="unet,unetplusplus,unet" \
  --model-paths="src/model/round_2/unet_mobilenet_v2/saved_weights.pth,src/model/round_2/unetplusplus_mobilenet_v2/saved_weights.pth,src/model/round_2/finetuned_unet_mobilenet_v2/saved_weights.pth" \
  --round=3 \
  --backbone="mobilenet_v2"
# Out:
# Number of test temporal-regions: 10
# Created final-ETCI-2021-Flood-Detection/data/test_internal dataframe with 10400 entries.
#                                        vv_image_path  ...    region
# 0  final-ETCI-2021-Flood-Detection/data/test_inte...  ...  florence
# 1  final-ETCI-2021-Flood-Detection/data/test_inte...  ...  florence
# 2  final-ETCI-2021-Flood-Detection/data/test_inte...  ...  florence
# 3  final-ETCI-2021-Flood-Detection/data/test_inte...  ...  florence
# 4  final-ETCI-2021-Flood-Detection/data/test_inte...  ...  florence
#
# [5 rows x 5 columns]
# Figure(1000x600)
# Predicting with src/model/round_2/unet_mobilenet_v2/saved_weights.pth: 100% 109/109 [00:39<00:00,  2.74it/s]
# Predicting with src/model/round_2/unetplusplus_mobilenet_v2/saved_weights.pth: 100% 109/109 [00:51<00:00,  2.10it/s]
# Predicting with src/model/round_2/finetuned_unet_mobilenet_v2/saved_weights.pth: 100% 109/109 [00:36<00:00,  2.98it/s]
# ...
